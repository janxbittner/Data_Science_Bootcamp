# %% [markdown]
# Import modules:

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %% [markdown]
# ## Data load:

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head()
# Out:
#                                                  URL  ...  Current Version Release Date
# 0   https://apps.apple.com/us/app/sudoku/id284921427  ...                    30/05/2017
# 1  https://apps.apple.com/us/app/reversi/id284926400  ...                    17/05/2018
# 2  https://apps.apple.com/us/app/morocco/id284946595  ...                     5/09/2017
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  ...                    30/05/2017
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  ...                    22/07/2018
#
# [5 rows x 18 columns]

# %% [markdown]
# # Data preprocessing

# %%
df_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %% [markdown]
# Remove unlesses column:

# %%
df = df.drop(columns=['URL', 'Icon URL', 'Subtitle', 'Description', 'In-app Purchases'])
df.head()
# Out:
#           ID           Name  ...  Original Release Date  Current Version Release Date
# 0  284921427         Sudoku  ...             11/07/2008                    30/05/2017
# 1  284926400        Reversi  ...             11/07/2008                    17/05/2018
# 2  284946595        Morocco  ...             11/07/2008                     5/09/2017
# 3  285755462  Sudoku (Free)  ...             23/07/2008                    30/05/2017
# 4  285831220   Senet Deluxe  ...             18/07/2008                    22/07/2018
#
# [5 rows x 13 columns]

# %% [markdown]
# Set Column ID as index column:

# %%
df = df.set_index('ID')
df.head()
# Out:
#                     Name  ...  Current Version Release Date
# ID                        ...
# 284921427         Sudoku  ...                    30/05/2017
# 284926400        Reversi  ...                    17/05/2018
# 284946595        Morocco  ...                     5/09/2017
# 285755462  Sudoku (Free)  ...                    30/05/2017
# 285831220   Senet Deluxe  ...                    22/07/2018
#
# [5 rows x 12 columns]

# %% [markdown]
# Statistisc about columns:

# %%
df.describe().T
# Out:
#                        count          mean  ...          75%           max
# Average User Rating   7561.0  4.060905e+00  ...          4.5  5.000000e+00
# User Rating Count     7561.0  3.306531e+03  ...        309.0  3.032734e+06
# Price                16983.0  8.134187e-01  ...          0.0  1.799900e+02
# Size                 17006.0  1.157064e+08  ...  133027072.0  4.005591e+09
#
# [4 rows x 8 columns]

# %%
df.describe(include=['object']).T
# Out:
#                               count  ...   freq
# Name                          17007  ...      2
# Developer                     17007  ...    123
# Age Rating                    17007  ...  11806
# Languages                     16947  ...  12467
# Primary Genre                 17007  ...  16286
# Genres                        17007  ...    778
# Original Release Date         17007  ...     75
# Current Version Release Date  17007  ...    118
#
# [8 rows x 4 columns]

# %% [markdown]
# Change the columns names:

# %%
df.columns
# Out:
# Index(['Name', 'Average User Rating', 'User Rating Count', 'Price',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df.columns = [col.lower().replace(' ', '_') for col in df.columns]
df.columns
# Out:
# Index(['name', 'average_user_rating', 'user_rating_count', 'price',
#        'developer', 'age_rating', 'languages', 'size', 'primary_genre',
#        'genres', 'original_release_date', 'current_version_release_date',
#        'num_lang'],
#       dtype='object')

# %% [markdown]
# # Data Exploration:

# %% [markdown]
# Application types in store:

# %%
types_df = pd.DataFrame(df.primary_genre.value_counts())
NB_of_games = types_df.primary_genre['Games']
NB_of_application= types_df.primary_genre.sum() - NB_of_games
px.pie(pd.DataFrame([NB_of_games,NB_of_application],index = ['Games','Applications'],
             columns = ['App_type']),values = 'App_type', 
       names = ['Games','Applications'],
       template = 'plotly_dark')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3f01016d-44cc-4f90-bc71-a4314dfb312b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f01016d-44cc-4f90-bc71-a4314dfb312b")) {
#                     Plotly.newPlot(
#                         '3f01016d-44cc-4f90-bc71-a4314dfb312b',
# ...

# %%
types_df = types_df.drop(index=types_df.idxmax())
app_by_type = px.bar(types_df,x = types_df.index,y = 'primary_genre',color='primary_genre',
       template = 'plotly_dark',
       title = 'Application types in store',
       labels = {'x':"Application genre",
                 'primary_genre':'Count'})
app_by_type.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ed28960-17c5-4424-8afa-78c044c1d6cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ed28960-17c5-4424-8afa-78c044c1d6cf")) {
#                     Plotly.newPlot(
#                         '1ed28960-17c5-4424-8afa-78c044c1d6cf',
# ...

# %% [markdown]
# Minimal age of app user:

# %%
age_df = pd.DataFrame(df.groupby(by = 'age_rating').size(),columns=['Count'])
app_by_age = px.bar(age_df,x= age_df.index,y = 'Count',color='Count',
       template = 'plotly_dark',
       title = 'Application by user age',
       labels = {'x':"Application by user age"}).update_xaxes(categoryorder = 'total descending')

app_by_age.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="88c5c43b-99e5-4742-959b-e20313a1355a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88c5c43b-99e5-4742-959b-e20313a1355a")) {
#                     Plotly.newPlot(
#                         '88c5c43b-99e5-4742-959b-e20313a1355a',
# ...

# %% [markdown]
# Apps by price:

# %%
price_df = df.price.value_counts().rename_axis('Prices in $').reset_index(name='counts')
price_df = price_df[price_df['Prices in $'] <= 10]
px.bar(price_df,x = 'Prices in $',y = 'counts', template = 'plotly_dark',
       title = 'Apps by price',range_x = [0,10], color ='Prices in $' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d3ab9222-79a6-497b-879e-1e56f3ad08ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d3ab9222-79a6-497b-879e-1e56f3ad08ef")) {
#                     Plotly.newPlot(
#                         'd3ab9222-79a6-497b-879e-1e56f3ad08ef',
# ...

# %%
rating_df = df.average_user_rating.value_counts().rename_axis('Rating').reset_index(name='counts')
app_br = px.bar(rating_df,x = 'Rating',y = 'counts', template = 'plotly_dark',
       title = 'Apps by user rating', color ='Rating' )
app_br.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="66ebe572-1228-44f4-b007-1f68f68db62b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66ebe572-1228-44f4-b007-1f68f68db62b")) {
#                     Plotly.newPlot(
#                         '66ebe572-1228-44f4-b007-1f68f68db62b',
# ...

# %% [markdown]
# Apps by language:

# %%
temp_dict = {}
for row in df.languages:
    temp_list = row.split(', ')
    for lang in temp_list:
        if lang in temp_dict.keys():
            temp_dict[lang] += 1
        else:
            temp_dict[lang] = 1

lang_df = pd.DataFrame.from_dict(data = temp_dict,orient = 'index',
                                 columns = ['Count'])
lang_df = lang_df[lang_df.Count > 100]
lang_plot = px.bar(lang_df, y = lang_df.Count,x = lang_df.index,
                   color = 'Count',
                   title = "Apps by supported language",
                   template = 'plotly_dark')
lang_plot.update_layout(xaxis={'categoryorder':'total descending'})

lang_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8b02d0da-691a-4d0c-aa46-af98c6af68c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b02d0da-691a-4d0c-aa46-af98c6af68c7")) {
#                     Plotly.newPlot(
#                         '8b02d0da-691a-4d0c-aa46-af98c6af68c7',
# ...

# %% [markdown]
# # Missing Data:

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...
