# %% [markdown]
# Import modules:

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as pdr

# %% [markdown]
# # Data load:

# %%
df = pdr.DataReader("AMZN.US", "stooq")
df
# Out:
#                Open      High      Low    Close   Volume
# Date
# 2020-11-06  3304.64  3322.000  3232.00  3311.37  4647330
# 2020-11-05  3319.97  3366.800  3288.88  3322.00  5789285
# 2020-11-04  3159.99  3244.850  3139.73  3241.16  6839041
# 2020-11-03  3018.53  3074.900  2980.98  3048.41  4897880
# 2020-11-02  3061.74  3079.705  2950.12  3004.48  7257350
# ...             ...       ...      ...      ...      ...
# 2015-11-16   640.92   649.990   622.29   647.81  7435900
# 2015-11-13   663.57   667.000   640.45   642.35  6261000
# 2015-11-12   673.00   675.640   664.22   665.60  4284600
# 2015-11-11   663.25   675.960   663.25   673.25  5387300
# 2015-11-10   651.01   660.000   647.26   659.68  3489400
#
# [1258 rows x 5 columns]

# %% [markdown]
# Information about columns:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2020-11-06 to 2015-11-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1258 non-null   float64
#  1   High    1258 non-null   float64
#  2   Low     1258 non-null   float64
#  3   Close   1258 non-null   float64
#  4   Volume  1258 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB

# %% [markdown]
# # Data exploration:

# %% [markdown]
# Change columns name into small letter:

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')

# %% [markdown]
# Statistics about columns:

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1484.596188  1500.198473  1466.792163  1484.300783  4.318406e+06
# std     705.860329   716.095854   693.951076   705.230667  2.154077e+06
# min     478.010000   493.500000   474.000000   482.070000  8.813370e+05
# 25%     839.582500   844.130000   833.290000   840.377500  2.851330e+06
# 50%    1562.835000  1582.390000  1540.730000  1561.520000  3.748463e+06
# 75%    1850.687500  1870.287500  1831.652500  1855.320000  5.220101e+06
# max    3547.000000  3552.250000  3486.685000  3531.450000  1.655260e+07

# %% [markdown]
# # Data processing:

# %% [markdown]
# Sort data in dataframe from oldes date to newest:

# %%
sorted_df = df.sort_index()
sorted_df
# Out:
#                open      high      low    close   volume
# Date
# 2015-11-10   651.01   660.000   647.26   659.68  3489400
# 2015-11-11   663.25   675.960   663.25   673.25  5387300
# 2015-11-12   673.00   675.640   664.22   665.60  4284600
# 2015-11-13   663.57   667.000   640.45   642.35  6261000
# 2015-11-16   640.92   649.990   622.29   647.81  7435900
# ...             ...       ...      ...      ...      ...
# 2020-11-02  3061.74  3079.705  2950.12  3004.48  7257350
# 2020-11-03  3018.53  3074.900  2980.98  3048.41  4897880
# 2020-11-04  3159.99  3244.850  3139.73  3241.16  6839041
# 2020-11-05  3319.97  3366.800  3288.88  3322.00  5789285
# 2020-11-06  3304.64  3322.000  3232.00  3311.37  4647330
#
# [1258 rows x 5 columns]

# %% [markdown]
# Calculate dayly average price:

# %%
sorted_df['average_dayly'] = (sorted_df.open + sorted_df.close) / 2

# %% [markdown]
# Dayly close procentage change:

# %%
sorted_df["procentage_change"] = (sorted_df.close
 / sorted_df.close.shift(periods = 1) ) - 1
sorted_df
# Out:
#                open      high  ...  average_dayly  procentage_change
# Date                           ...
# 2015-11-10   651.01   660.000  ...        655.345                NaN
# 2015-11-11   663.25   675.960  ...        668.250           0.020571
# 2015-11-12   673.00   675.640  ...        669.300          -0.011363
# 2015-11-13   663.57   667.000  ...        652.960          -0.034931
# 2015-11-16   640.92   649.990  ...        644.365           0.008500
# ...             ...       ...  ...            ...                ...
# 2020-11-02  3061.74  3079.705  ...       3033.110          -0.010431
# 2020-11-03  3018.53  3074.900  ...       3033.470           0.014621
# 2020-11-04  3159.99  3244.850  ...       3200.575           0.063230
# 2020-11-05  3319.97  3366.800  ...       3320.985           0.024942
# 2020-11-06  3304.64  3322.000  ...       3308.005          -0.003200
#
# [1258 rows x 7 columns]

# %% [markdown]
# 5 minimal values from procentage change column:

# %%
sorted_df.procentage_change.nsmallest(5)
# Out:
# Date
# 2020-03-12   -0.079221
# 2016-01-29   -0.078288
# 2018-10-26   -0.078197
# 2020-05-01   -0.075974
# 2016-02-05   -0.063645
# Name: procentage_change, dtype: float64

# %% [markdown]
# 5 maximal values from procentage change column:

# %%
sorted_df.procentage_change.nlargest(5)
# Out:
# Date
# 2017-10-27    0.132164
# 2016-04-29    0.095664
# 2018-12-26    0.094452
# 2016-01-28    0.089140
# 2020-07-20    0.079295
# Name: procentage_change, dtype: float64

# %% [markdown]
# # Plots:

# %% [markdown]
# Import module:

# %%
import plotly.express as px

# %% [markdown]
# Histogram of dayly procentage change:

# %%
px.histogram(
    data_frame = sorted_df,
    x = 'procentage_change',
    nbins =100,
    marginal="violin",
    template = 'plotly_dark',
    title = 'Histogram of procentage close price change:'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a826cbf8-936d-48d4-8b05-d3e915e8422b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a826cbf8-936d-48d4-8b05-d3e915e8422b")) {
#                     Plotly.newPlot(
#                         'a826cbf8-936d-48d4-8b05-d3e915e8422b',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "procentage_change=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 100, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [null, 0.020570579674993983, -0.01136279242480498, -0.03493088942307687, 0.008500038919591946, -0.006961917846282084, 0.03146277009171472, -0.003421044699641329, 0.010857894657250622, 0.01576782107861474, -0.011546561805033995, 0.00624301571928787, -0.003079930109278317, -0.012565724979948345, 0.02145006016847173, -0.004491502959974025, -0.014437656247688668, 0.009590994371482253, -0.0041775689819218975, 0.011196870847827167, -0.01851387063912724, -0.0037154590171331048, -0.03347324556105824, 0.02774349761774575, 0.0011095742578772771, 0.026008137981294865, -0.007576542314692847, -0.00970700067099084, 0.0005571114524045573, -0.002046620818347389, 0.0008293749528764938, -0.0013711014012356415, 0.01872387935846964, 0.02779917061611381, -0.007060823954926021, -0.019127229454191985, -0.0575537439524183, -0.0050236267445329386, -0.0017987030404392756, -0.03905793092547205, -0.00146396025923623, 0.017609752079730034, 0.00024282060413760576, -0.05839227046885376, 0.019233082965229187, -0.038482293423271585, 0.007541478129713619, -0.004717309566912742, 0.005684103748010649, 0.0371465340335988, 0.0002515174888493288, 0.007912426868724065, -0.029771309771309706, 0.08914031027684932, -0.07828755803887621, -0.018442308020696463, -0.039508707224996, -0.03809092555696425, 0.00977272299320231, -0.0636445008018498, -0.027940971461573594, -0.012354025814382386, 0.017445599186840077, 0.027197847007013554, 0.006470564884283991, 0.02764849727853602, 0.024947227019765927,
.28, 898.28, 894.88, 907.04, 902.36, 896.23, 884.67, 901.99, 903.78, 899.2, 902.06, 898.53, 907.41, 907.63, 909.29, 918.38, 924.99, 948.23, 946.94, 941.03, 937.53, 934.15, 949.04, 952.82, 948.95, 947.62, 961.35, 957.97, 966.07, 944.76, 958.49, 959.84, 970.67, 971.54, 980.35, 993.38, 995.78, 996.7, 994.62, 995.95, 1006.73, 1011.34, 1003.0, 1010.07, 1010.27, 978.31, 964.91, 980.79, 976.47, 964.17, 987.71, 995.17, 992.59, 1002.23, 1001.3, 1003.74, 993.98, 976.78, 990.33, 975.93, 968.0, 953.66, 971.4, 965.14, 978.76, 996.47, 994.13, 1006.51, 1000.63, 1001.81, 1010.04, 1024.45, 1026.87, 1028.7, 1025.67, 1038.95, 1040.13, 1052.8, 1046.0, 1020.04, 987.78, 996.19, 995.89, 986.92, 987.41, 992.27, 989.84, 982.01, 956.92, 967.99, 983.3, 982.74, 978.18, 960.57, 958.47, 953.29, 966.9, 958.0, 952.45, 945.26, 946.02, 954.06, 967.59, 980.6, 978.25, 965.27, 967.8, 979.47, 965.9, 977.96, 982.58, 999.6, 992.21, 986.79, 974.19, 969.86, 973.21, 964.65, 955.1, 939.79, 938.6, 950.87, 956.4, 961.35, 959.19, 957.1, 965.45, 980.85, 989.51, 990.99, 987.2, 995.0, 1000.93, 1002.94, 1006 ...

# %% [markdown]
# # Filtering data:

# %% [markdown]
# Dataframe where procentage dayly change was positive:

# %%
positiv = sorted_df[sorted_df.procentage_change > 0 ]
print(f"Minimal procentage change in new dataframe is: {np.min(positiv.procentage_change):.5f}")
# Out:
# Minimal procentage change in new dataframe is: 0.00005

# %% [markdown]
# Average medium positive daily change:

# %%
print(f"{sorted_df.procentage_change.mean():4f} %")
# Out:
# 0.001467 %

# %% [markdown]
# Days where close value was equal to high:

# %%
print(sorted_df[sorted_df.close == sorted_df.high].index)
# Out:
# DatetimeIndex(['2016-12-07', '2018-01-05', '2018-01-10', '2018-02-23',
#                '2018-05-09', '2018-05-23', '2019-12-23', '2020-01-02',
#                '2020-05-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# Data frame only with data from month May:

# %%
may_df = sorted_df[sorted_df.index.month == 5]
may_df
# Out:
#                open       high  ...  average_dayly  procentage_change
# Date                            ...
# 2016-05-02   663.92   685.5000  ...        673.885           0.036780
# 2016-05-03   677.36   680.3000  ...        674.340          -0.018323
# 2016-05-04   662.59   674.0000  ...        666.785          -0.000506
# 2016-05-05   673.31   676.4900  ...        666.180          -0.017780
# 2016-05-06   656.05   676.9500  ...        665.000           0.022608
# ...             ...        ...  ...            ...                ...
# 2020-05-22  2455.01  2469.8500  ...       2445.945          -0.004030
# 2020-05-26  2458.00  2462.0000  ...       2439.930          -0.006164
# 2020-05-27  2404.99  2413.5800  ...       2407.690          -0.004736
# 2020-05-28  2384.33  2436.9699  ...       2392.715          -0.003854
# 2020-05-29  2415.94  2442.3700  ...       2429.155           0.017188
#
# [107 rows x 7 columns]
